# %% [markdown]
# # Impact of Covid19 on the Suicidal Rate
#
# ________________________________________________________________________________________________________

# %%
# Mute the warnings
import shutup; shutup.please()

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import requests
from pprint import pprint
import urllib


from api_keys import api_key

# %%
# Study data files
gdp_usd_path = "world_country_gdp_usd.csv"
homicide_path = "suicide_homicide_gdp.csv"
master_path = "master.csv"

# %%
# Read the data and the study results
gdp_usd = pd.read_csv(gdp_usd_path)
homicide = pd.read_csv(homicide_path)
master = pd.read_csv(master_path)

# %%
homicide
# Out:
#            country iso3c iso2c  year  \
# 0      Afghanistan   AFG    AF  1970
# 1      Afghanistan   AFG    AF  1971
# 2      Afghanistan   AFG    AF  1972
# 3      Afghanistan   AFG    AF  1973
# 4      Afghanistan   AFG    AF  1974
# ...            ...   ...   ...   ...
# 13561     Zimbabwe   ZWE    ZW  2016
# 13562     Zimbabwe   ZWE    ZW  2017
# 13563     Zimbabwe   ZWE    ZW  2018
# 13564     Zimbabwe   ZWE    ZW  2019
# 13565     Zimbabwe   ZWE    ZW  2020
#
#        Intentional homicides (per 100,000 people)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 13561                                         NaN
# 13562                                         NaN
# 13563                                         NaN
# ...

# %%
narrow_data = homicide.loc[(homicide["year"]<2021) & (homicide["year"]>=2019)]
#narrow_data
narrow_1 = pd.DataFrame(narrow_data, columns=["country", "year", "Suicide mortality rate (per 100,000 population)"])
narrow_1
narrow_1.dropna()
# Out:
#                            country  year  \
# 49                     Afghanistan  2019
# 100    Africa Eastern and Southern  2019
# 151     Africa Western and Central  2019
# 202                        Albania  2019
# 253                        Algeria  2019
# ...                            ...   ...
# 13258                      Vietnam  2019
# 13411                        World  2019
# 13462                  Yemen, Rep.  2019
# 13513                       Zambia  2019
# 13564                     Zimbabwe  2019
#
#        Suicide mortality rate (per 100,000 population)
# 49                                            4.100000
# 100                                           8.036293
# 151                                           5.409499
# 202                                           4.300000
# 253                                           2.500000
# ...                                                ...
# 13258                                         7.500000
# ...

# %%
master.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years         21.0      312900
# 1  Albania  1987    male  35-54 years         16.0      308000
# 2  Albania  1987  female  15-24 years         14.0      289700
# 3  Albania  1987    male    75+ years          1.0       21800
# 4  Albania  1987    male  25-34 years          9.0      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,15,66,24,900
# 1               5.19  Albania1987           NaN     2,15,66,24,900
# 2               4.83  Albania1987           NaN     2,15,66,24,900
# 3               4.59  Albania1987           NaN     2,15,66,24,900
# 4               3.28  Albania1987           NaN     2,15,66,24,900
#
#    gdp_per_capita ($)       generation
# 0               796.0     Generation X
# 1               796.0           Silent
# 2               796.0     Generation X
# ...

# %%
narrow_data_2 = master.loc[(master["year"]<2021) & (master["year"]>2017)]
narrow_data_3 = narrow_data_2.loc[(narrow_data_2["suicides/100k pop"]>0)]
#narrow_data_2
narrow_3 = pd.DataFrame(narrow_data_3, columns=["country", "year", "age", "suicides/100k pop"])
narrow_3
narrow_3.dropna()
# Out:
#                         country  year         age  suicides/100k pop
# 27823                 Australia  2020  5-14 years           0.058467
# 27824                   Austria  2020  5-14 years           0.022429
# 27834                Costa Rica  2020  5-14 years           0.019519
# 27838                   Czechia  2020  5-14 years           0.028043
# 27841                   Ecuador  2020  5-14 years           0.250162
# ...                         ...   ...         ...                ...
# 31669                   Ukraine  2018   75+ years           0.549050
# 31670            United Kingdom  2018   75+ years           0.139933
# 31671  United States of America  2018   75+ years           0.157570
# 31672                   Uruguay  2018   75+ years           0.554414
# 31673                Uzbekistan  2018   75+ years           0.006069
#
# [1639 rows x 4 columns]

# %%
group_by = narrow_3.groupby(["year"])['suicides/100k pop'].mean()
group_by
# Out:
# year
# 2018    7.058232
# 2019    7.392679
# 2020    0.902171
# Name: suicides/100k pop, dtype: float64

# %%
combined_data_df = pd.merge(narrow_1, narrow_3, on=["country", "year"] )
combined_data_df
# Out:
#         country  year  Suicide mortality rate (per 100,000 population)  \
# 0     Argentina  2019                                              8.4
# 1     Argentina  2019                                              8.4
# 2     Argentina  2019                                              8.4
# 3     Argentina  2019                                              8.4
# 4     Argentina  2019                                              8.4
# ..          ...   ...                                              ...
# 782  Uzbekistan  2019                                              8.0
# 783  Uzbekistan  2019                                              8.0
# 784  Uzbekistan  2019                                              8.0
# 785  Uzbekistan  2019                                              8.0
# 786  Uzbekistan  2019                                              8.0
#
#              age  suicides/100k pop
# 0     5-14 years           0.086785
# 1    15-24 years           1.544326
# ...

# %%
combined_data_df = combined_data_df.fillna({"Suicide mortality rate (per 100,000 population)": 0})
combined_data_df
# Out:
#          country  year_x  Suicide mortality rate (per 100,000 population)  \
# 0      Argentina    2019                                              8.4
# 1      Argentina    2019                                              8.4
# 2      Argentina    2019                                              8.4
# 3      Argentina    2019                                              8.4
# 4      Argentina    2019                                              8.4
# ...          ...     ...                                              ...
# 2921  Uzbekistan    2020                                              0.0
# 2922  Uzbekistan    2020                                              0.0
# 2923  Uzbekistan    2020                                              0.0
# 2924  Uzbekistan    2020                                              0.0
# 2925  Uzbekistan    2020                                              0.0
#
#       year_y          age  suicides/100k pop
# ...

# %%
group_by = combined_data_df.groupby(["year"])['suicides/100k pop'].mean()
group_by
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 group_by = combined_data_df.groupby(["year"])['suicides/100k pop'].mean()
#       2 group_by
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
group_by_df = pd.DataFrame(group_by)
group_by_df
# Out:
#       suicides/100k pop
# year
# 2019           0.826539
# 2020           0.927781

# %%
plot = group_by_df.plot(kind="bar", color = "b", align = "center")

plot
# Out:
# <Axes: xlabel='year'>

# %%
group_by_1 = combined_data_df.groupby(["year"])["Suicide mortality rate (per 100,000 population)"].mean()
group_by_1
# Out:
# year
# 2019    11.026786
# 2020     0.000000
# Name: Suicide mortality rate (per 100,000 population), dtype: float64

# %%
#x = combined_data_df["year"]
#y = combined_data_df["Suicide mortality rate (per 100,000 population)"]
#plt.plot(x, y, color = "b")
#correlation = st.pearsonr(x,y)
#plt.show

# %%
url = "https://world-bank-gdp.p.rapidapi.com/"

units = "metric"

#query_url = "https://world-bank-gdp.p.rapidapi.com/?rapidapi-key=c97a853d6emshcb9922ce69eb038p1296bcjsn7bd619f192a3"
query_url = "http://api.worldbank.org/v2/country/?format=json"




#headers = {
#"content-type": "application/octet-stream",
#"api_keys": "c97a853d6emshcb9922ce69eb038p1296bcjsn7bd619f192a3",
#"X-RapidAPI-Host": "world-bank-gdp.p.rapidapi.com"
#}

country_data = requests.get(query_url).json()


#if (response_1.status_code != 204 and response.headers["content-type"].strip().startswith("application/json")):
    #try:
        #return response_1.json()
    #except ValueError:

pprint(response_1)
# Out:
# [{'page': 1, 'pages': 6, 'per_page': '50', 'total': 299},
#  [{'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'capitalCity': 'Oranjestad',
#    'id': 'ABW',
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'iso2Code': 'AW',
#    'latitude': '12.5167',
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'longitude': '-70.0167',
#    'name': 'Aruba',
#    'region': {'id': 'LCN',
#               'iso2code': 'ZJ',
#               'value': 'Latin America & Caribbean '}},
#   {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'capitalCity': '',
#    'id': 'AFE',
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'iso2Code': 'ZH',
#    'latitude': '',
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'longitude': '',
#    'name': 'Africa Eastern and Southern',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
# ...

# %%
counties = []

record_count = 1
set_count = 1

for i, country in enumerate(countries):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    record_count += 1
    try:
        # Parse the JSON and retrieve data
        country_data = requests.get(query_url).json()
        country_name = country_data["name"]
        income_level = country_data["incomeLevel"]["value"]
        
        
       

        # Append the City information into city_data list
        countries.append({"country": country_name, "income level": income_level})

    # If an error is experienced, skip the city
    except:
        print("country not found. Skipping...")
        pass
              





print(f"Number of countries in the list: {len(countries)}")
# Out:
# Number of countries in the list: 0
